# %%
import pandas as pd

query = """
SELECT *
FROM SAPSR3.main branch
"""

df = pd.read_sql(query, connection)

df
# Out:
# NameError: name 'connection' is not defined
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 8
#       1 import pandas as pd
#       3 query = """
#       4 SELECT *
#       5 FROM SAPSR3.AAA_EMPLOYEE_RELATION_1
#       6 """
# ----> 8 df = pd.read_sql(query, connection)
#      10 df
#
# NameError: name 'connection' is not defined
